# %% [markdown]
# <a href="https://colab.research.google.com/github/ssstevensong/AMATH679_Project/blob/Code/Project679.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Print("pop")
